# %% [markdown]
# <a href="https://colab.research.google.com/github/sifatbhuiyan0909/Dhaka-Finance-Navigator/blob/main/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this is some basics of

# %%
print('hello my friends . this is just the beginning of the finance ai i am going to create. my plan is to build this because i find this work hard and so it becomses extremely interesting to learn and make')
# Out:
# hello my friends . this is just the beginning of the finance ai i am going to create. my plan is to build this because i find this work hard and so it becomses extremely interesting to learn and make

# %%
stock_symbol= 'GP'
price = 280.50
volume= 1500000
print(f'{stock_symbol}: price: {price}')
# Out:
# GP: price: 280.5

# %%
top_stocks = ["GP", "BATBC", "SQUARE"]
print(top_stocks)
# Out:
# ['GP', 'BATBC', 'SQUARE']

# %%
stock_data = { "name": "Grameenphone",
              "price": 280.50,
               "volume": 1500000 }
print(f"Volume: {stock_data['volume']}")
# Out:
# Volume: 1500000

# %%
today_price = 285
target = 280
if today_price > target:
  print("Price is above the target.")
else:
    print("Price is low.")
# Out:
# Price is above the target.
